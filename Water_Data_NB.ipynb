# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import tabula

# %%
#Reading the file
df=tabula.read_pdf('River-Water.pdf',pages='all')
# Out:
# Got stderr: Sep 21, 2021 2:45:39 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_181
# Sep 21, 2021 2:45:39 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Sep 21, 2021 2:45:39 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Sep 21, 2021 2:45:39 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Sep 21, 2021 2:45:39 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Sep 21, 2021 2:45:39 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
df[0]
# Out:
#     Statio\rn Code                                   LOCATION  \
# 2           1001.0                         BEAS AT U/S MANALI
# 3           4444.0           RIVER BEAS D/S OF WPF AT\rMANALI
# 4           4037.0             RIVER BEAS D/S MANALSU\rNALLAH
# 5           2601.0                         BEAS AT D/S MANALI
# 6           2602.0                          BEAS AT U/S KULLU
# 7           4445.0            RIVER BEAS D/S OF WPF AT\rKULLU
# 8           1002.0                           BEAS AT D/S KULU
# 9           1003.0                            BEAS AT D/S AUT
# 10          1004.0                     BEAS AT U/S PANDOH DAM
# 11          2603.0                     BEAS AT D/S PANDOH DAM
# 12          1005.0  BEAS AT EXIT OF TUNNEL\rDEHAL POWER HOUSE
# 13          1550.0                             BEAS U/S MANDI
# 14          1006.0                          BEAS AT D/S MANDI
# 15          2604.0                    BEAS AT D/S JAISINGHPUR
# ...

# %%
df[0].iloc[0]
# Out:
# Statio\rn Code                                       1001
# LOCATION                               BEAS AT U/S MANALI
# STATE                                   HIMACHAL\rPRADESH
# Temperature\r(0 C)                                      2
# Dissolved\rOxygen\r(mg/ L)                             13
# pH                                                    8.7
# Conductivity\r(μmho/ Cm)                             11.2
# Bio-Chemical\rOxygen\rDemand (mg/L)                   7.3
# Nitrate\r(mg/ L)                                      8.4
# Faecal Coliform\r(MPN/ 100 mL)                         90
# Total Coliform\r(MPN/ 100 mL)                         179
# Faecal\rStreptococci\r(MPN/ 100 mL)                   0.1
# Unnamed: 0                                            0.2
# Unnamed: 1                                            0.2
# Unnamed: 2                                           0.31
# Unnamed: 3                                             12
# ...

# %%
len(df)
# Out:
# 82

# %%
df[0].iloc[2:]
# Out:
#     Statio\rn Code                                   LOCATION  \
# 4           4037.0             RIVER BEAS D/S MANALSU\rNALLAH
# 5           2601.0                         BEAS AT D/S MANALI
# 6           2602.0                          BEAS AT U/S KULLU
# 7           4445.0            RIVER BEAS D/S OF WPF AT\rKULLU
# 8           1002.0                           BEAS AT D/S KULU
# 9           1003.0                            BEAS AT D/S AUT
# 10          1004.0                     BEAS AT U/S PANDOH DAM
# 11          2603.0                     BEAS AT D/S PANDOH DAM
# 12          1005.0  BEAS AT EXIT OF TUNNEL\rDEHAL POWER HOUSE
# 13          1550.0                             BEAS U/S MANDI
# 14          1006.0                          BEAS AT D/S MANDI
# 15          2604.0                    BEAS AT D/S JAISINGHPUR
# 16          1007.0                        BEAS AT D/S ALAMPUR
# 17          3855.0      BEAS D/S NADAUN BRIDGE,\rVILL BHADOLI
#
# ...

# %%
for i in range(len(df)):
    df[i]=df[i].iloc[2:]

# %%
df[0]
# Out:
#     Statio\rn Code                                   LOCATION  \
# 2           1001.0                         BEAS AT U/S MANALI
# 3           4444.0           RIVER BEAS D/S OF WPF AT\rMANALI
# 4           4037.0             RIVER BEAS D/S MANALSU\rNALLAH
# 5           2601.0                         BEAS AT D/S MANALI
# 6           2602.0                          BEAS AT U/S KULLU
# 7           4445.0            RIVER BEAS D/S OF WPF AT\rKULLU
# 8           1002.0                           BEAS AT D/S KULU
# 9           1003.0                            BEAS AT D/S AUT
# 10          1004.0                     BEAS AT U/S PANDOH DAM
# 11          2603.0                     BEAS AT D/S PANDOH DAM
# 12          1005.0  BEAS AT EXIT OF TUNNEL\rDEHAL POWER HOUSE
# 13          1550.0                             BEAS U/S MANDI
# 14          1006.0                          BEAS AT D/S MANDI
# 15          2604.0                    BEAS AT D/S JAISINGHPUR
# ...

# %%
obj=[df[i] for i in range(len(df))]

# %%
df_2=pd.concat(obj)

# %%
df_2.shape
# Out:
# (1571, 42)

# %%
df_2.head(10)
# Out:
#    Statio\rn Code                          LOCATION              STATE  \
# 2            1001                BEAS AT U/S MANALI  HIMACHAL\rPRADESH
# 3            4444  RIVER BEAS D/S OF WPF AT\rMANALI  HIMACHAL\rPRADESH
# 4            4037    RIVER BEAS D/S MANALSU\rNALLAH  HIMACHAL\rPRADESH
# 5            2601                BEAS AT D/S MANALI  HIMACHAL\rPRADESH
# 6            2602                 BEAS AT U/S KULLU  HIMACHAL\rPRADESH
# 7            4445   RIVER BEAS D/S OF WPF AT\rKULLU  HIMACHAL\rPRADESH
# 8            1002                  BEAS AT D/S KULU  HIMACHAL\rPRADESH
# 9            1003                   BEAS AT D/S AUT  HIMACHAL\rPRADESH
# 10           1004            BEAS AT U/S PANDOH DAM  HIMACHAL\rPRADESH
# 11           2603            BEAS AT D/S PANDOH DAM  HIMACHAL\rPRADESH
#
#    Temperature\r(0 C) Dissolved\rOxygen\r(mg/ L)   pH  \
# 2                   2                         13  8.7
# 3                   8                         14  8.5
# ...

# %%
df_2.columns
# Out:
# Index(['Statio\rn Code', 'LOCATION', 'STATE', 'Temperature\r(0 C)',
#        'Dissolved\rOxygen\r(mg/ L)', 'pH', 'Conductivity\r(μmho/ Cm)',
#        'Bio-Chemical\rOxygen\rDemand (mg/L)', 'Nitrate\r(mg/ L)',
#        'Faecal Coliform\r(MPN/ 100 mL)', 'Total Coliform\r(MPN/ 100 mL)',
#        'Faecal\rStreptococci\r(MPN/ 100 mL)', 'Unnamed: 0', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Bio-Chemical\rOxygen\rDemand (Mg/L)',
#        'Total Coliform (MPN/ 100\rmL)', 'Dissolved', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Faecal -\rStreptococci\r(MPN/ 100 mL)',
#        'Bio-Chemical', 'Faecal', 'Temperature', 'Dissolved\rOxygen', 'Nitrate',
#        'Faecal Coliform', 'Temperat\rure\r(0 C)',
#        'Bio-Chemical Oxygen\rDemand (mg/L)',
#        'Faecal\rStreptoc\rocci\r(MPN/\r100 mL)', 'Dissolved Oxygen\r(mg/ L)',
#        'Bio-Chemical\rOxygen Demand\r(mg/L)',
# ...

# %%
df_2=df_2[['Statio\rn Code', 'LOCATION', 'STATE', 'Temperature\r(0 C)','Dissolved\rOxygen\r(mg/ L)', 'pH', 'Conductivity\r(μmho/ Cm)','Bio-Chemical\rOxygen\rDemand (mg/L)', 'Nitrate\r(mg/ L)','Faecal Coliform\r(MPN/ 100 mL)', 'Total Coliform\r(MPN/ 100 mL)','Faecal\rStreptococci\r(MPN/ 100 mL)', 'Unnamed: 0', 'Unnamed: 1','Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6','Unnamed: 7', 'Unnamed: 8']]

# %%
df_2.shape
# Out:
# (1571, 21)

# %%
df_2
# Out:
#    Statio\rn Code                              LOCATION              STATE  \
# 2            1001                    BEAS AT U/S MANALI  HIMACHAL\rPRADESH
# 3            4444      RIVER BEAS D/S OF WPF AT\rMANALI  HIMACHAL\rPRADESH
# 4            4037        RIVER BEAS D/S MANALSU\rNALLAH  HIMACHAL\rPRADESH
# 5            2601                    BEAS AT D/S MANALI  HIMACHAL\rPRADESH
# 6            2602                     BEAS AT U/S KULLU  HIMACHAL\rPRADESH
# ..            ...                                   ...                ...
# 10           2387    SUBAREKHA AT GHATISLA\rROAD BRIDGE          JHARKHAND
# 11           2395            SUBARNAREKHA AT HATIA\rDAM          JHARKHAND
# 12           2397         SUBARNAREKHA AT\rGATALSUD DAM          JHARKHAND
# 13           2399          SUBARNAREKHA AT CHANDIL\rDAM          JHARKHAND
# 14           1641  SUBARNAREKHA AT RAJGHAT\r(THENGUDIA)             ODISHA
#
#    Temperature\r(0 C) Dissolved\rOxygen\r(mg/ L)   pH  \
# ...

# %%
df_2.dropna(axis=0,inplace=True)

# %%
df_2['Unnamed: 7'].replace(to_replace=['--','-'],value=0,inplace=True)

# %%
df_2['Unnamed: 7'].value_counts()
# Out:
# 0      290
# 170      2
# 79       1
# 23       1
# 31       1
# Name: Unnamed: 7, dtype: int64

# %%
df_2['Unnamed: 8'].replace(to_replace=['--','-'],value=0,inplace=True)

# %%
df_2['Unnamed: 8'].value_counts()
# Out:
# 0      290
# 700      1
# 23       1
# 490      1
# 31       1
# 170      1
# Name: Unnamed: 8, dtype: int64

# %%
df_2
# Out:
#    Statio\rn Code                           LOCATION              STATE  \
# 2            1001                 BEAS AT U/S MANALI  HIMACHAL\rPRADESH
# 3            4444   RIVER BEAS D/S OF WPF AT\rMANALI  HIMACHAL\rPRADESH
# 4            4037     RIVER BEAS D/S MANALSU\rNALLAH  HIMACHAL\rPRADESH
# 5            2601                 BEAS AT D/S MANALI  HIMACHAL\rPRADESH
# 6            2602                  BEAS AT U/S KULLU  HIMACHAL\rPRADESH
# ..            ...                                ...                ...
# 7               7             NARMADA AT GARUDESHWAR            GUJARAT
# 8            1244                NARMADA AT PANETHA,            GUJARAT
# 9            1245                NARMADA AT CHANDOD,            GUJARAT
# 10           1981  NARMADA AT ZANOR (NTPC),\rBHARUCH            GUJARAT
# 11           1243    NARMADA AT BHARUCH,\rZADESHVAR,            GUJARAT
#
#    Temperature\r(0 C) Dissolved\rOxygen\r(mg/ L)   pH  \
# ...

# %%
df_2.drop(['Statio\rn Code','LOCATION','STATE'], axis=1, inplace=True)

# %%
df_2
# Out:
#    Temperature\r(0 C) Dissolved\rOxygen\r(mg/ L)   pH  \
# 2                   2                         13  8.7
# 3                   8                         14  8.5
# 4                   2                         13  8.9
# 5                   3                         14  8.2
# 6                   5                         15  7.6
# ..                ...                        ...  ...
# 7                  26                         30  6.2
# 8                  25                         31  6.3
# 9                  20                         30    7
# 10                 26                         30  6.1
# 11                 27                         30  5.9
#
#    Conductivity\r(μmho/ Cm) Bio-Chemical\rOxygen\rDemand (mg/L)  \
# 2                      11.2                                 7.3
# 3                      10.8                                 7.3
# 4                      10.9                                   7
# ...

# %%
df_2['Unnamed: 8'].replace(to_replace=['-','--','__','BDL'],value=0,inplace=True)

# %%
df_2['Unnamed: 8']=df_2['Unnamed: 8'].astype('float')

# %%
df_3['Faecal Streptococci (MPN/ 100 mL)']=df_2['Unnamed: 5']+df_2['Unnamed: 6']

# %%
df_3['Faecal Streptococci (MPN/ 100 mL)']=df_3['Total Coliform\r(MPN/ 100 mL)']/2

# %%
df_3['Faecal Streptococci (MPN/ 100 mL)']
# Out:
# 2      90.00
# 3     205.00
# 4     100.00
# 5     300.00
# 6     190.00
#        ...
# 7      28.00
# 8      27.75
# 9      60.75
# 10     35.00
# 11    140.00
# Name: Faecal Streptococci (MPN/ 100 mL), Length: 295, dtype: float64

# %%
df_3['Conductivity (μmho/ Cm)']=df_3['Conductivity\r(μmho/ Cm)']

# %%
df_3.drop(['Conductivity\r(μmho/ Cm)'],axis=1,inplace=True)

# %%
df_3
# Out:
#     Temperature  Dissolved Oxygen    pH  Bio-Chemical Oxygen Demand (mg/L)  \
# 2           7.5              9.95  7.85                               0.15
# 3          11.0              9.65  7.70                               0.45
# 4           7.5              9.90  7.65                               0.55
# 5           8.5              9.65  7.55                               0.35
# 6          10.0              9.55  7.80                               0.25
# ..          ...               ...   ...                                ...
# 7          28.0              6.95  7.85                               0.37
# 8          28.0              6.90  7.95                               0.60
# 9          25.0              7.40  7.70                               0.55
# 10         28.0              6.75  7.90                               0.70
# 11         28.5              6.50  7.95                               0.90
#
#     Faecal Streptococci (MPN/ 100 mL)  Nitrate (mg/ L)  \
# ...

# %%
df_3.to_csv('Data_MADE.csv')
